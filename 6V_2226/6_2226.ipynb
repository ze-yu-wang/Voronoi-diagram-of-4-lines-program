# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_26 = load_configs_from_yaml("6_26_short.yaml")
configs_22 = load_configs_from_yaml("6_22_short.yaml")
check_configs(configs_26, 6, 2, 6)
check_configs(configs_22, 6, 2, 2)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_26, configs_22, 6, 2226)
# Out:
# Configuration tuple 1
#     B(1,2): Config241, B(1,3): Config322_4, B(2,3): Config323_2.
#     B(1,4): Config314_5, B(2,4): Config141=Config142_1, B(3,4): Config142_8.
#
# Configuration tuple 2
#     B(1,2): Config243, B(1,3): Config321_1, B(2,3): Config321_1.
#     B(1,4): Config141=Config142_1, B(2,4): Config141=Config142_1, B(3,4): Config333_18=Config333_33.
#
# The total number of possible configuration tuple is 2.
