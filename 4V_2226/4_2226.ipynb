# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_26 = load_configs_from_yaml("4_26_short.yaml")
configs_22 = load_configs_from_yaml("4_22_short.yaml")
check_configs(configs_26, 4, 2, 6)
check_configs(configs_22, 4, 2, 2)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_26, configs_22, 4, 2226)
# Out:
# Potential combination case 1
#     B(1,2): Config251, B(1,3): Config251, B(2,3): Config244_2.
#     B(1,4): Config153_3=Config153_4=Config153_7=Config153_8=Config153_9=Config153_10=Config153_13=Config153_14, B(2,4): Config151=Config152, B(3,4): Config151=Config152.
#
# Potential combination case 2
#     B(1,2): Config251, B(1,3): Config322, B(2,3): Config324_2.
#     B(1,4): Config144_1, B(2,4): Config151=Config152, B(3,4): Config142.
#
# Potential combination case 3
#     B(1,2): Config321, B(1,3): Config321, B(2,3): Config254_12=Config254_15.
#     B(1,4): Config143, B(2,4): Config151=Config152, B(3,4): Config151=Config152.
#
# Potential combination case 4
#     B(1,2): Config323, B(1,3): Config323, B(2,3): Config244_1.
#     B(1,4): Config143, B(2,4): Config314, B(3,4): Config314.
#
# The total number of potential combination is 4.
