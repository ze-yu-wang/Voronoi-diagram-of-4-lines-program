# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_04 = load_configs_from_yaml("6_04_short.yaml")
configs_44 = load_configs_from_yaml("6_44_short.yaml")
check_configs(configs_04, 6, 0, 4)
check_configs(configs_44, 6, 4, 4)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_04, configs_44, 6, 4440)
# Out:
# Potential combination case 1
#     B(1,2): Config161=Config162_1, B(1,3): Config161=Config162_1, B(2,3): Config214_5.
#     B(1,4): Config353_24=Config353_59, B(2,4): Config342_8, B(3,4): Config342_8.
#
# Potential combination case 2
#     B(1,2): Config233_4=Config233_19, B(1,3): Config121_4=Config122_3, B(2,3): Config121_4=Config122_3.
#     B(1,4): Config341, B(2,4): Config341, B(3,4): Config343.
#
# Potential combination case 3
#     B(1,2): Config234_2=Config234_7, B(1,3): Config121_5=Config122_7, B(2,3): Config121_5=Config122_7.
#     B(1,4): Config341, B(2,4): Config341, B(3,4): Config343.
#
# Potential combination case 4
#     B(1,2): Config214_6, B(1,3): Config214_6, B(2,3): Config214_6.
#     B(1,4): Config343, B(2,4): Config343, B(3,4): Config343.
#
# The total number of potential combination is 4.
