# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_04 = load_configs_from_yaml("8_04_short.yaml")
configs_44 = load_configs_from_yaml("8_44_short.yaml")
check_configs(configs_04, 8, 0, 4)
check_configs(configs_44, 8, 4, 4)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_04, configs_44, 8, 4440)
# Out:
# The total number of potential combination is 0.
