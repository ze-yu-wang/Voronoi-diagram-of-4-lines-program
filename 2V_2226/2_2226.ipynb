# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_26 = load_configs_from_yaml("2_26.yaml")
configs_22 = load_configs_from_yaml("2_22.yaml")
check_configs(configs_26, 2, 2, 6)
check_configs(configs_22, 2, 2, 2)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_26, configs_22, 2, 2226)
# Out:
# Potential combination case 1
#     B(1,2): Config253, B(1,3): Config324, B(2,3): Config324.
#     B(1,4): Config144, B(2,4): Config144, B(3,4): Config333.
#
# The total number of potential combination is 1.
