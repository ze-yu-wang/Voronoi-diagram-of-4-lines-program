# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_26 = load_configs_from_yaml("0_26_no.yaml")
configs_22 = load_configs_from_yaml("0_22_no.yaml")
check_configs(configs_26, 0, 2, 6)
check_configs(configs_22, 0, 2, 2)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_26, configs_22, 0, 2226)
# Out:
# Configuration tuple 1
#     B(1,2): Config254, B(1,3): Config254, B(2,3): Config254.
#     B(1,4): Config153, B(2,4): Config153, B(3,4): Config153.
#
# The total number of possible configuration tuple is 1.
