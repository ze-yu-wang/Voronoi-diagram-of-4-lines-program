# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from trimodel import *
from itertools import combinations_with_replacement, product, combinations, chain
import networkx as nx

# %%
with open("helper.yaml", "r") as f:
    helper_data = yaml.safe_load(f)

# Create a quick lookup from name to list of commands
helper_dict = {entry["name"]: entry["commands_list"] for entry in helper_data}

# %%
configs = load_configs_from_yaml("0_22_no.yaml")
add_twist_and_write(helper_dict, configs, 4, "8_22.yaml")

# %%
shorten_configs("8_22.yaml")
