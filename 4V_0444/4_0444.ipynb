# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_04 = load_configs_from_yaml("4_04_short.yaml")
configs_44 = load_configs_from_yaml("4_44_short.yaml")
check_configs(configs_04, 4, 0, 4)
check_configs(configs_44, 4, 4, 4)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_04, configs_44, 4, 4440)
# Out:
# Potential combination case 1
#     B(1,2): Config121=Config122, B(1,3): Config162, B(2,3): Config123_1=Config123_2=Config124_1.
#     B(1,4): Config344_3, B(2,4): Config342, B(3,4): Config352.
#
# The total number of potential combination is 1.
