# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_04 = load_configs_from_yaml("2_04_no.yaml")
configs_44 = load_configs_from_yaml("2_44_no.yaml")
check_configs(configs_04, 2, 0, 4)
check_configs(configs_44, 2, 4, 4)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_04, configs_44, 2, 4440)
# Out:
# Potential combination case 1
#     B(1,2): Config123, B(1,3): Config123, B(2,3): Config234.
#     B(1,4): Config353, B(2,4): Config344, B(3,4): Config344.
#
# Potential combination case 2
#     B(1,2): Config124, B(1,3): Config124, B(2,3): Config233.
#     B(1,4): Config353, B(2,4): Config344, B(3,4): Config344.
#
# The total number of potential combination is 2.
