# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from trimodel import *

# %%
configs_26 = load_configs_from_yaml("8_26_short.yaml")
configs_22 = load_configs_from_yaml("8_22_short.yaml")
check_configs(configs_26, 8, 2, 6)
check_configs(configs_22, 8, 2, 2)
# Out:
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.
# Checking the unbounded part of the trisectors in the configuration ......
# Test passed.
# Checking the vertices of the trisectors in the configuration ......
# Test passed.

# %%
get_valid_comb(configs_26, configs_22, 8, 2226)
# Out:
# The total number of possible configuration tuple is 0.
